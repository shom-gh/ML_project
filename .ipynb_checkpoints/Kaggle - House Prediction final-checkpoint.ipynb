# %% [markdown]
# # House Prediction

# %% [markdown]
# <p><a name="sections"></a></p>
# - <a href="#target">Exploring the target variable</a><br>
# - <a href="#Feature Engineering">Feature Engineering</a><br>
#     - <a href="#Merge">Merge train and test set</a><br>
#     - <a href="#Missing">Impute missing values</a><br>
#     - <a href="#Label">Label Encoding</a><br>
#     - <a href="#New">New Features</a><br>
#     - <a href="#Skew">Skewness</a><br>
#     - <a href="#Outliers">Remove Outliers</a><br>
#     - <a href="#Dummy">Get dummies</a><br>
# - <a href="#Modeling">Predictive Modeling</a><br>
#     - <a href="#Split">Split in train and test set</a><br>
#     - <a href="#Linear">Linear Models</a><br>
#         - <a href="#ex1">Exercise 1</a><br>
#     - <a href="#classes">Logistic Regression with More than Two Classes</a><br>
#         - <a href="#ex2">Exercise 2</a><br>

# %%
import pandas as pd
import pandas as pd
import numpy as np
import math
import seaborn as sns
from scipy import stats
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df_train = pd.read_csv('./train.csv')
df_test = pd.read_csv('./test.csv')

# %%
train_id = df_train['Id']
test_id = df_test['Id']
print(train_id.shape)
print(test_id.shape)
# Out:
# (1460,)
# (1459,)

# %%
df_train = df_train.drop(['Id'], axis = 1)
df_test = df_test.drop(['Id'], axis = 1)
print(df_train.shape)
print(df_test.shape)
# Out:
# (1460, 80)
# (1459, 79)

# %% [markdown]
# <p><a name="target"></a></p>
# ## Exploring the target variable

# %%
print(df_train['SalePrice'].describe())
dist = sns.distplot(df_train['SalePrice'])
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
prob_plot = stats.probplot(df_train['SalePrice'], plot=plt)

# %% [markdown]
# #### Log transformation

# %%
df_train['SalePrice'] = np.log(df_train['SalePrice'])

# %%
dist = sns.distplot(df_train['SalePrice'])

# %%
prob_plot = stats.probplot(df_train['SalePrice'], plot=plt)

# %% [markdown]
# #### Remove Outliers

# %%
plt.scatter(x = 'GrLivArea', y = 'SalePrice', data = df_train)
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')

# %%
df_train.loc[(df_train['GrLivArea']>4500)]['GrLivArea']
# Out:
# 523     4676
# 1298    5642
# Name: GrLivArea, dtype: int64

# %%
df_train = df_train.drop(df_train[(df_train['GrLivArea'] > 4500)].index)

# %%
plt.scatter(x = 'GrLivArea', y = 'SalePrice', data = df_train)
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')

# %% [markdown]
# <p><a name="Feature Engineering"></a></p>
# ## Feature Engineering

# %% [markdown]
# - Merge train and test set
# - Impute missing values
# - Transform original variables
# - Derive new features
# - Categorical encoding

# %% [markdown]
# <p><a name="Merge"></a></p>
# ### Merge train and test set

# %%
frames = [df_train, df_test]
df_all = pd.concat(frames)

df_all.shape
# Out:
# (2917, 80)

# %% [markdown]
# <p><a name="Missing"></a></p>
#
# ### Impute missing values

# %%
#Calculat the ratio of missing values
missing = (df_all.isnull().sum(axis=0) / len(df_all)*100).sort_values(ascending=False)

#Dropping all with non-missing values
missing = missing.drop(missing[missing==0].index)

missing_data = pd.DataFrame({'Missing Ratio' :missing})
missing_data
# Out:
#               Missing Ratio
# PoolQC            99.691464
# MiscFeature       96.400411
# Alley             93.212204
# Fence             80.425094
# SalePrice         50.017141
# FireplaceQu       48.680151
# LotFrontage       16.660953
# GarageQual         5.450806
# GarageYrBlt        5.450806
# GarageFinish       5.450806
# GarageCond         5.450806
# GarageType         5.382242
# BsmtCond           2.811107
# BsmtExposure       2.811107
# BsmtQual           2.776826
# BsmtFinType2       2.742544
# BsmtFinType1       2.708262
# MasVnrType         0.822763
# MasVnrArea         0.788481
# MSZoning           0.137127
# BsmtHalfBath       0.068564
# Utilities          0.068564
# Functional         0.068564
# BsmtFullBath       0.068564
# Electrical         0.034282
# Exterior2nd        0.034282
# KitchenQual        0.034282
# GarageCars         0.034282
# Exterior1st        0.034282
# GarageArea         0.034282
# TotalBsmtSF        0.034282
# BsmtUnfSF          0.034282
# BsmtFinSF2         0.034282
# BsmtFinSF1         0.034282
# SaleType           0.034282

# %% [markdown]
# #### Categorical features

# %%
list_none = ['PoolQC', 'GarageType', 'GarageFinish', 'GarageCond', 'GarageQual', 'BsmtQual', 'BsmtCond', 
             'BsmtExposure', 'BsmtFinType2', 'BsmtFinType1', 'MasVnrType', 'Alley', 'Fence', 'FireplaceQu', 'MiscFeature']

# Replace with "None"
df_all[list_none] = df_all[list_none].fillna('None')
# Replace with the mode
df_all['MSZoning'] = df_all['MSZoning'].fillna(df_all['MSZoning'].mode()[0])
df_all['Functional'] = df_all['Functional'].fillna(df_all['Functional'].mode()[0])
df_all['Exterior1st'] = df_all['Exterior1st'].fillna(df_all['Exterior1st'].mode()[0])

# %% [markdown]
# #### Numeric features

# %%
list_null = ['GarageYrBlt', 'GarageArea', 'GarageCars', 'BsmtFinSF1' , 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
               'BsmtFullBath', 'BsmtHalfBath', 'MasVnrArea', 'Exterior2nd', 'KitchenQual', 'SaleType', 'Electrical']

# Replace with 0
df_all[list_null] = df_all[list_null].fillna(0)
# Replace with the median of the neighborhood
df_all['LotFrontage'] = df_all.groupby('Neighborhood')['LotFrontage'].transform(lambda x: x.fillna(x.median()))
df_all.loc[df_all.LotFrontage.isnull(), 'LotFrontage'] = np.sqrt(df_all.loc[df_all.LotFrontage.isnull()].LotArea)

# %% [markdown]
# #### Dropping variables

# %%
df_all = df_all.drop(['Utilities'], axis = 1)

# %% [markdown]
# #### Converting numerical features to categorical

# %%
df_all = df_all.replace({"MSSubClass" : {20 : "SC20", 30 : "SC30", 40 : "SC40", 45 : "SC45", 
                                       50 : "SC50", 60 : "SC60", 70 : "SC70", 75 : "SC75", 
                                       80 : "SC80", 85 : "SC85", 90 : "SC90", 120 : "SC120", 
                                       150 : "SC150", 160 : "SC160", 180 : "SC180", 190 : "SC190"},
                       "MoSold" : {1 : "Jan", 2 : "Feb", 3 : "Mar", 4 : "Apr", 5 : "May", 6 : "Jun",
                                   7 : "Jul", 8 : "Aug", 9 : "Sep", 10 : "Oct", 11 : "Nov", 12 : "Dec"}
                      })

df_all['YrSold'] = df_all['YrSold'].astype(str)
df_all['OverallCond'] = df_all['OverallCond'].astype(str)

# %% [markdown]
# #### Update missingness table

# %%
#axis=0, summing each row for each column
#isnull = return an boolean depending on missing or not

#Calculat the ratio of missing values
missing1 = (df_all.isnull().sum(axis=0) / len(df_all)*100).sort_values(ascending=False)

#Dropping all 
missing1 = missing1.drop(missing1[missing1==0].index)

missing_data_updated = pd.DataFrame({'Missing Ratio' :missing1})
missing_data_updated
# Out:
#            Missing Ratio
# SalePrice      50.017141

# %% [markdown]
# <p><a name="Label"></a></p>
# ### Label Encoding

# %%
# Label encode on every categorical variable that contains an order
# SUGGESTION: maintain the order or try use labelcount encoding
from sklearn.preprocessing import LabelEncoder
columns = ('FireplaceQu', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond',
       'ExterQual', 'ExterCond','HeatingQC', 'PoolQC', 'KitchenQual', 'BsmtFinType1',
       'BsmtFinType2', 'Functional', 'Fence', 'BsmtExposure', 'GarageFinish', 'LandSlope',
       'LotShape', 'PavedDrive', 'Street', 'Alley', 'CentralAir', 'MSSubClass', 'OverallCond',
       'YrSold', 'MoSold')

for column in columns:
   lbl = LabelEncoder()
   lbl.fit(list(df_all[column].values))
   df_all[column] = lbl.transform(list(df_all[column].values))
      
print(df_all.shape)
# Out:
# (2917, 79)

# %% [markdown]
# <p><a name="New"></a></p>
# ### New Features

# %%
# 1: Total square feet
df_all['TotLivArea'] = df_all.TotalBsmtSF + df_all['1stFlrSF'] + df_all['2ndFlrSF']

# 2: # Total number of bathrooms
df_all['TotalBath'] = df_all['BsmtFullBath'] + (0.5 * df_all['BsmtHalfBath']) + df_all['FullBath'] + (0.5 * df_all['HalfBath'])

# 3: BsmtUnFinRatio
df_all['BsmtUnFinRatio'] = df_all.BsmtUnfSF / df_all.TotalBsmtSF 
df_all['BsmtUnFinRatio'] = df_all['BsmtUnFinRatio'].fillna(0)

# 4: AreaPerCar
df_all['AreaPerCar'] = df_all.GarageArea / df_all.GarageCars 
df_all['AreaPerCar'] = df_all['AreaPerCar'].fillna(0)

# 5: AvgRoomSize 
df_all['AvgRoomSize'] = df_all.GrLivArea / df_all.TotRmsAbvGrd

# 6: GarageScore
df_all['GarageScore'] = df_all.GarageCond * df_all.GarageType

# 7: OverallGrade
df_all["OverallGrade"] = df_all["OverallQual"] * df_all["OverallCond"]

# 8: Overallscore
df_all["Overallscore"] = df_all["OverallGrade"]  * df_all['GrLivArea']

# df_all["ExterGrade"] = df_all["ExterQual"] * df_all["ExterCond"]
# df_all["TotalBath"] = df_all["BsmtFullBath"] + (0.5 * df_all["BsmtHalfBath"]) + \
# df_all["FullBath"] + (0.5 * df_all["HalfBath"])
# df_all["AllPorchSF"] = df_all["OpenPorchSF"] + df_all["EnclosedPorch"] + \
# df_all["3SsnPorch"] + df_all["ScreenPorch"]

# %% [markdown]
# <p><a name="Skew"></a></p>
# ### Skewness

# %%
from scipy.stats import skew, kurtosis
from scipy.special import boxcox1p


numerical_features = list(df_all.select_dtypes(exclude = ['object']).columns)

skewness = df_all[numerical_features].apply(lambda x: skew(x))
skewness = skewness[abs(skewness) > 0.7]
print(str(skewness.shape[0]) + " skewed numerical features to log transform")
skewed_features = skewness.index
print(skewness)
# Out:
# 47 skewed numerical features to log transform
# 1stFlrSF          1.257286
# 2ndFlrSF          0.861556
# 3SsnPorch        11.372080
# BsmtCond         -2.861271
# BsmtExposure     -1.117321
# BsmtFinSF1        0.980645
# BsmtFinSF2        4.144503
# BsmtFinType2     -3.042979
# BsmtHalfBath      3.929996
# BsmtUnfSF         0.919688
# CentralAir       -3.457555
# EnclosedPorch     4.002344
# ExterCond        -2.496489
# ExterQual        -1.800062
# Fence            -1.992649
# Fireplaces        0.725278
# Functional       -4.054126
# GarageCond       -3.594290
# GarageQual       -3.072788
# GarageYrBlt      -3.904632
# GrLivArea         1.068750
# KitchenAbvGr      4.300550
# KitchenQual      -1.455671
# LandSlope         4.973254
# LotArea          13.109495
# LotFrontage       1.103039
# LowQualFinSF     12.084539
# MasVnrArea        2.621719
# MiscVal          21.939672
# OpenPorchSF       2.529358
# OverallCond       0.890152
# PavedDrive       -2.977741
# PoolArea         17.688664
# PoolQC          -21.217600
# ScreenPorch       3.945101
# Street          -15.494756
# TotRmsAbvGrd      0.749232
# WoodDeckSF        1.844792
# TotLivArea        1.009157
# AvgRoomSize       0.931704
# OverallGrade      1.076786
# FireScore         1.612836
# Overallscore      2.549744
# ExterGrade       -1.156422
# KitchenScore      1.393231
# AllSF             1.011805
# AllPorchSF        2.244500
# dtype: float64

# %% [markdown]
# #### Box cox transformation of skewed variables

# %%
lamda = 0.15
for column in skewed_features:
    df_all[column] = boxcox1p(df_all[column], lamda)

# %% [markdown]
# <p><a name="Dummy"></a></p>
#
# ### Get dummies

# %%
df_all = pd.get_dummies(df_all, drop_first = True)
print(df_all.shape)
# Out:
# (2917, 231)

# %% [markdown]
# <p><a name="Modeling"></a></p>
# ## Predictive Modeling

# %% [markdown]
# <p><a name="Split"></a></p>
# ### Split to train and test set

# %%
train = df_all[df_all.SalePrice.notnull()]
test = df_all[df_all.SalePrice.isnull()]
y = train.SalePrice
train = train.drop(['SalePrice'], axis = 1)
test = test.drop(['SalePrice'], axis = 1)

# %%
print(train.shape)
print(test.shape)
print(y.shape)
# Out:
# (1458, 230)
# (1459, 230)
# (1458,)

# %% [markdown]
# <p><a name="Linear"></a></p>
# ### Linear Models

# %%
from sklearn import linear_model
from sklearn.model_selection import GridSearchCV, KFold, cross_val_score
from sklearn import preprocessing

# %% [markdown]
# #### Lasso Regression

# %%
lasso = linear_model.Lasso()

# %% [markdown]
# #### Ridge Regression

# %%
ridge = linear_model.Ridge()

# %%
# Specify parameters
grid_param = [{'alpha': np.logspace(-4, 4, 500), 'random_state': [42]}]

# %%
# Normalize
X_norm_train = preprocessing.normalize(train, axis = 0)
X_norm_test = preprocessing.normalize(test, axis = 0)

# %%
# GridsearchCV
param_search = GridSearchCV(estimator = ridge, param_grid = grid_param, cv = 10, verbose = 1).fit(X_norm_train, y)
# Out:
# Fitting 10 folds for each of 500 candidates, totalling 5000 fits
# [Parallel(n_jobs=1)]: Done 5000 out of 5000 | elapsed:  1.3min finished

# %%
param_search.grid_scores_
print("R-square: ", param_search.best_score_)
print(param_search.best_params_)
# Out:
# R-square:  0.905735504253
# {'random_state': 42, 'alpha': 0.00050747052394904658}
# /Users/madshelt/anaconda/envs/py35/lib/python3.5/site-packages/sklearn/model_selection/_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)

# %%
best_fit_ridge = param_search.best_estimator_
fitted_ridge = best_fit_ridge.fit(X_norm_train,y)
print("R-square: ", fitted_ridge.score(X_norm_train,y))
# Out:
# R-square:  0.940998696369

# %%
predicted_ridge = fitted_ridge.predict(X_norm_train)
print("MSE: ", np.mean((predicted_ridge - y)**2))
print("RMSE: ", np.sqrt(np.mean((predicted_ridge - y)**2)))
# Out:
# MSE:  0.009420315529243497
# RMSE:  0.0970583099443

# %% [markdown]
# #### Alternative Ridge Regression

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler

# %%
n_folds = 5

def rmsle_cv(model):
   kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(train.values)
   rmse= np.sqrt(-cross_val_score(model, train.values, y, scoring="neg_mean_squared_error", cv = kf))
   return(rmse)

# %%
lasso = make_pipeline(RobustScaler(), linear_model.Lasso(alpha =0.0005))

# %%
score = rmsle_cv(lasso)
print(np.mean(score))
# Out:
# 0.128914939361

# %%
# Out:
# array([ 0.11247539,  0.12703184,  0.13584123,  0.11469575,  0.11417335])

# %% [markdown]
# #### Submitting to Kaggle

# %%
SalePrice = best_fit_ridge.predict(X_norm_test)

# %%
ridge_result = round(pd.DataFrame(np.exp(SalePrice)), 3) # transforming log y back to original value

# %%
ridge_result = ridge_result.set_index(test_id)
ridge_result.columns = ['SalePrice']
ridge_result.to_csv("ridge1.csv")
